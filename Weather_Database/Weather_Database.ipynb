# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mogadishu
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | great falls
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | port lincoln
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 1 | saint-augustin
# Processing Record 12 of Set 1 | paamiut
# Processing Record 13 of Set 1 | nanning
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | tilichiki
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | karratha
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | quatre cocos
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | norman wells
# Processing Record 28 of Set 1 | takoradi
# Processing Record 29 of Set 1 | naron
# Processing Record 30 of Set 1 | druzhba
# Processing Record 31 of Set 1 | esperance
# Processing Record 32 of Set 1 | apam
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | saint anthony
# Processing Record 36 of Set 1 | basco
# Processing Record 37 of Set 1 | touros
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 1 | emmett
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | skibbereen
# Processing Record 45 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 1 | tarko-sale
# Processing Record 47 of Set 1 | nicolas de pierola
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | asau
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | sambava
# Processing Record 4 of Set 2 | san patricio
# Processing Record 5 of Set 2 | mezen
# Processing Record 6 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 2 | rawson
# Processing Record 8 of Set 2 | reporoa
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | arroyo
# Processing Record 12 of Set 2 | litoral del san juan
# City not found. Skipping...
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | fairbanks
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | cayenne
# Processing Record 17 of Set 2 | khani
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | samarai
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | manzanillo
# Processing Record 25 of Set 2 | grande-riviere
# City not found. Skipping...
# Processing Record 26 of Set 2 | qui nhon
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | cabo san lucas
# Processing Record 29 of Set 2 | camacha
# Processing Record 30 of Set 2 | yerbogachen
# Processing Record 31 of Set 2 | caravelas
# Processing Record 32 of Set 2 | ust-tsilma
# Processing Record 33 of Set 2 | inhambane
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | vila franca do campo
# Processing Record 36 of Set 2 | poum
# Processing Record 37 of Set 2 | hobyo
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | bengkulu
# Processing Record 40 of Set 2 | kajaani
# Processing Record 41 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | narsaq
# Processing Record 45 of Set 2 | los llanos de aridane
# Processing Record 46 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 2 | vila velha
# Processing Record 48 of Set 2 | nsanje
# Processing Record 49 of Set 2 | klaksvik
# Processing Record 50 of Set 2 | nanortalik
# Processing Record 1 of Set 3 | batagay-alyta
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | silvania
# Processing Record 5 of Set 3 | lubango
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | nara
# Processing Record 10 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 3 | el bagre
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 3 | kungurtug
# Processing Record 19 of Set 3 | port alfred
# Processing Record 20 of Set 3 | lincoln
# Processing Record 21 of Set 3 | vestmannaeyjar
# Processing Record 22 of Set 3 | ocote paulino
# Processing Record 23 of Set 3 | lavrentiya
# Processing Record 24 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 3 | camocim
# Processing Record 26 of Set 3 | pisco
# Processing Record 27 of Set 3 | anshun
# Processing Record 28 of Set 3 | mitu
# Processing Record 29 of Set 3 | vao
# Processing Record 30 of Set 3 | yar-sale
# Processing Record 31 of Set 3 | sargur
# Processing Record 32 of Set 3 | aloleng
# Processing Record 33 of Set 3 | roald
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | kindersley
# Processing Record 36 of Set 3 | smolenka
# Processing Record 37 of Set 3 | quzhou
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | mecca
# Processing Record 40 of Set 3 | veletma
# City not found. Skipping...
# Processing Record 41 of Set 3 | ha giang
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | barrow
# Processing Record 44 of Set 3 | clyde river
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | harper
# Processing Record 47 of Set 3 | lagoa
# Processing Record 48 of Set 3 | saint-pierre
# Processing Record 49 of Set 3 | vicosa do ceara
# Processing Record 50 of Set 3 | beihai
# Processing Record 1 of Set 4 | ivybridge
# Processing Record 2 of Set 4 | brae
# Processing Record 3 of Set 4 | atasu
# Processing Record 4 of Set 4 | tsiroanomandidy
# Processing Record 5 of Set 4 | pangoa
# Processing Record 6 of Set 4 | olinda
# Processing Record 7 of Set 4 | maniitsoq
# Processing Record 8 of Set 4 | saint pete beach
# Processing Record 9 of Set 4 | bari
# Processing Record 10 of Set 4 | haines junction
# Processing Record 11 of Set 4 | mahebourg
# Processing Record 12 of Set 4 | beachwood
# Processing Record 13 of Set 4 | pacific grove
# Processing Record 14 of Set 4 | ketchikan
# Processing Record 15 of Set 4 | gat
# Processing Record 16 of Set 4 | peachland
# Processing Record 17 of Set 4 | hasaki
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | tasiilaq
# Processing Record 21 of Set 4 | hami
# Processing Record 22 of Set 4 | airai
# Processing Record 23 of Set 4 | havelock
# Processing Record 24 of Set 4 | bambous virieux
# Processing Record 25 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 4 | sorong
# Processing Record 27 of Set 4 | roma
# Processing Record 28 of Set 4 | nome
# Processing Record 29 of Set 4 | cherskiy
# Processing Record 30 of Set 4 | severo-kurilsk
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | santiago de cao
# Processing Record 34 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 35 of Set 4 | edd
# Processing Record 36 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 4 | husavik
# Processing Record 38 of Set 4 | berdigestyakh
# Processing Record 39 of Set 4 | port hedland
# Processing Record 40 of Set 4 | atengo
# Processing Record 41 of Set 4 | kloulklubed
# Processing Record 42 of Set 4 | laguna
# Processing Record 43 of Set 4 | luderitz
# Processing Record 44 of Set 4 | sakakah
# Processing Record 45 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 4 | wasilla
# Processing Record 47 of Set 4 | kokopo
# Processing Record 48 of Set 4 | aksarka
# Processing Record 49 of Set 4 | kavieng
# Processing Record 50 of Set 4 | ailigandi
# Processing Record 1 of Set 5 | manbij
# Processing Record 2 of Set 5 | dukat
# Processing Record 3 of Set 5 | corinto
# Processing Record 4 of Set 5 | rio grande
# Processing Record 5 of Set 5 | dingle
# Processing Record 6 of Set 5 | banswada
# Processing Record 7 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 5 | glossop
# Processing Record 9 of Set 5 | kalmunai
# Processing Record 10 of Set 5 | killybegs
# Processing Record 11 of Set 5 | ucluelet
# Processing Record 12 of Set 5 | tevaitoa
# Processing Record 13 of Set 5 | ierapetra
# Processing Record 14 of Set 5 | beroroha
# Processing Record 15 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 5 | mandera
# Processing Record 17 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 5 | vuktyl
# Processing Record 19 of Set 5 | egvekinot
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | ballina
# Processing Record 22 of Set 5 | sioux lookout
# Processing Record 23 of Set 5 | belaya gora
# Processing Record 24 of Set 5 | kristinehamn
# Processing Record 25 of Set 5 | menongue
# Processing Record 26 of Set 5 | tual
# Processing Record 27 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 5 | nioro
# Processing Record 29 of Set 5 | ilulissat
# Processing Record 30 of Set 5 | esna
# Processing Record 31 of Set 5 | henties bay
# Processing Record 32 of Set 5 | juneau
# Processing Record 33 of Set 5 | hay river
# Processing Record 34 of Set 5 | kattivakkam
# Processing Record 35 of Set 5 | guerrero negro
# Processing Record 36 of Set 5 | changde
# Processing Record 37 of Set 5 | vostok
# Processing Record 38 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 5 | agadir
# Processing Record 40 of Set 5 | naze
# Processing Record 41 of Set 5 | petatlan
# Processing Record 42 of Set 5 | bay roberts
# Processing Record 43 of Set 5 | oranjemund
# Processing Record 44 of Set 5 | longyearbyen
# Processing Record 45 of Set 5 | marshfield
# Processing Record 46 of Set 5 | aleksandrovskoye
# Processing Record 47 of Set 5 | sinnamary
# Processing Record 48 of Set 5 | coquimbo
# Processing Record 49 of Set 5 | moose factory
# Processing Record 50 of Set 5 | lolodorf
# Processing Record 1 of Set 6 | broken hill
# Processing Record 2 of Set 6 | morganton
# Processing Record 3 of Set 6 | port hardy
# Processing Record 4 of Set 6 | half moon bay
# Processing Record 5 of Set 6 | mnogovershinnyy
# Processing Record 6 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 6 | znamenskoye
# Processing Record 8 of Set 6 | oistins
# Processing Record 9 of Set 6 | saint george
# Processing Record 10 of Set 6 | mount isa
# Processing Record 11 of Set 6 | paracuru
# Processing Record 12 of Set 6 | hebertville
# City not found. Skipping...
# Processing Record 13 of Set 6 | torbay
# Processing Record 14 of Set 6 | richards bay
# Processing Record 15 of Set 6 | yichang
# Processing Record 16 of Set 6 | adrar
# Processing Record 17 of Set 6 | murgab
# Processing Record 18 of Set 6 | katsuura
# Processing Record 19 of Set 6 | veraval
# Processing Record 20 of Set 6 | komsomolskiy
# Processing Record 21 of Set 6 | sorland
# Processing Record 22 of Set 6 | lucea
# Processing Record 23 of Set 6 | varia
# Processing Record 24 of Set 6 | flin flon
# Processing Record 25 of Set 6 | mali
# Processing Record 26 of Set 6 | itapetinga
# Processing Record 27 of Set 6 | naryan-mar
# Processing Record 28 of Set 6 | morondava
# Processing Record 29 of Set 6 | san cristobal
# Processing Record 30 of Set 6 | cardston
# Processing Record 31 of Set 6 | oum hadjer
# Processing Record 32 of Set 6 | meulaboh
# Processing Record 33 of Set 6 | gunjur
# Processing Record 34 of Set 6 | saint-philippe
# Processing Record 35 of Set 6 | sug-aksy
# City not found. Skipping...
# Processing Record 36 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 6 | atar
# Processing Record 38 of Set 6 | trat
# Processing Record 39 of Set 6 | tselinnoye
# Processing Record 40 of Set 6 | smithers
# Processing Record 41 of Set 6 | buala
# Processing Record 42 of Set 6 | quchan
# Processing Record 43 of Set 6 | gobindapur
# Processing Record 44 of Set 6 | andenes
# Processing Record 45 of Set 6 | nantucket
# Processing Record 46 of Set 6 | maragogi
# Processing Record 47 of Set 6 | bairiki
# Processing Record 48 of Set 6 | constantine
# Processing Record 49 of Set 6 | torrington
# Processing Record 50 of Set 6 | vavoua
# Processing Record 1 of Set 7 | snasa
# Processing Record 2 of Set 7 | shu
# Processing Record 3 of Set 7 | aranos
# Processing Record 4 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 7 | codrington
# Processing Record 6 of Set 7 | constitucion
# Processing Record 7 of Set 7 | anori
# Processing Record 8 of Set 7 | havoysund
# Processing Record 9 of Set 7 | kununurra
# Processing Record 10 of Set 7 | vieques
# Processing Record 11 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | labuhan
# Processing Record 13 of Set 7 | auki
# Processing Record 14 of Set 7 | ambunti
# Processing Record 15 of Set 7 | buchanan
# Processing Record 16 of Set 7 | pascagoula
# Processing Record 17 of Set 7 | baruun-urt
# Processing Record 18 of Set 7 | jiaohe
# Processing Record 19 of Set 7 | bertoua
# Processing Record 20 of Set 7 | okha
# Processing Record 21 of Set 7 | heidelberg
# Processing Record 22 of Set 7 | mar del plata
# Processing Record 23 of Set 7 | kieta
# Processing Record 24 of Set 7 | padang
# Processing Record 25 of Set 7 | ustka
# Processing Record 26 of Set 7 | lorengau
# Processing Record 27 of Set 7 | hoi an
# Processing Record 28 of Set 7 | vanimo
# Processing Record 29 of Set 7 | acheng
# Processing Record 30 of Set 7 | esqueda
# Processing Record 31 of Set 7 | aklavik
# Processing Record 32 of Set 7 | hualmay
# Processing Record 33 of Set 7 | ankazobe
# Processing Record 34 of Set 7 | axim
# Processing Record 35 of Set 7 | beisfjord
# Processing Record 36 of Set 7 | talaya
# Processing Record 37 of Set 7 | umm kaddadah
# Processing Record 38 of Set 7 | magdagachi
# Processing Record 39 of Set 7 | vacha
# Processing Record 40 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 41 of Set 7 | lunca
# Processing Record 42 of Set 7 | manggar
# Processing Record 43 of Set 7 | flinders
# Processing Record 44 of Set 7 | ylojarvi
# Processing Record 45 of Set 7 | awjilah
# Processing Record 46 of Set 7 | bilibino
# Processing Record 47 of Set 7 | obo
# Processing Record 48 of Set 7 | upernavik
# Processing Record 49 of Set 7 | cariati
# Processing Record 50 of Set 7 | sherman
# Processing Record 1 of Set 8 | geraldton
# Processing Record 2 of Set 8 | sogdiondon
# City not found. Skipping...
# Processing Record 3 of Set 8 | forestville
# Processing Record 4 of Set 8 | vero beach
# Processing Record 5 of Set 8 | playa del carmen
# Processing Record 6 of Set 8 | shelburne
# Processing Record 7 of Set 8 | creel
# Processing Record 8 of Set 8 | saldanha
# Processing Record 9 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 8 | klyuchevskiy
# Processing Record 11 of Set 8 | pryshyb
# Processing Record 12 of Set 8 | khandyga
# Processing Record 13 of Set 8 | yumen
# Processing Record 14 of Set 8 | seymchan
# Processing Record 15 of Set 8 | marawi
# Processing Record 16 of Set 8 | eirunepe
# Processing Record 17 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 8 | yima
# Processing Record 19 of Set 8 | santa rosa
# Processing Record 20 of Set 8 | circleville
# Processing Record 21 of Set 8 | seoul
# Processing Record 22 of Set 8 | kilinochchi
# Processing Record 23 of Set 8 | progreso
# Processing Record 24 of Set 8 | port augusta
# Processing Record 25 of Set 8 | kondinskoye
# Processing Record 26 of Set 8 | dhidhdhoo
# Processing Record 27 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 29 of Set 8 | mulege
# Processing Record 30 of Set 8 | venkatagiri
# Processing Record 31 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 8 | guarapari
# Processing Record 33 of Set 8 | rapid city
# Processing Record 34 of Set 8 | metro
# Processing Record 35 of Set 8 | bantou
# Processing Record 36 of Set 8 | rio gallegos
# Processing Record 37 of Set 8 | timiryazevskiy
# Processing Record 38 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 8 | hambantota
# Processing Record 40 of Set 8 | tuatapere
# Processing Record 41 of Set 8 | ajaccio
# Processing Record 42 of Set 8 | verkhnyaya inta
# Processing Record 43 of Set 8 | ugoofaaru
# Processing Record 44 of Set 8 | vydrino
# Processing Record 45 of Set 8 | bodden town
# Processing Record 46 of Set 8 | pudozh
# Processing Record 47 of Set 8 | kokoda
# Processing Record 48 of Set 8 | aleksandrovsk-sakhalinskiy
# Processing Record 49 of Set 8 | mocuba
# Processing Record 50 of Set 8 | asfi
# Processing Record 1 of Set 9 | les cayes
# Processing Record 2 of Set 9 | concepcion del uruguay
# Processing Record 3 of Set 9 | ostrovnoy
# Processing Record 4 of Set 9 | port-gentil
# Processing Record 5 of Set 9 | ambanja
# Processing Record 6 of Set 9 | lokosovo
# Processing Record 7 of Set 9 | nouadhibou
# Processing Record 8 of Set 9 | altar
# Processing Record 9 of Set 9 | dongsheng
# Processing Record 10 of Set 9 | avera
# Processing Record 11 of Set 9 | kosh-agach
# Processing Record 12 of Set 9 | fortuna
# Processing Record 13 of Set 9 | praia da vitoria
# Processing Record 14 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 9 | florence
# Processing Record 16 of Set 9 | vicuna
# Processing Record 17 of Set 9 | upington
# Processing Record 18 of Set 9 | kristiinankaupunki
# Processing Record 19 of Set 9 | calbuco
# Processing Record 20 of Set 9 | sarkand
# Processing Record 21 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 22 of Set 9 | khatanga
# Processing Record 23 of Set 9 | sidi bu zayd
# City not found. Skipping...
# Processing Record 24 of Set 9 | guhagar
# Processing Record 25 of Set 9 | mambatangan
# Processing Record 26 of Set 9 | nikolskoye
# Processing Record 27 of Set 9 | buluang
# Processing Record 28 of Set 9 | dera din panah
# City not found. Skipping...
# Processing Record 29 of Set 9 | portland
# Processing Record 30 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 9 | tura
# Processing Record 32 of Set 9 | maun
# Processing Record 33 of Set 9 | gazimurskiy zavod
# Processing Record 34 of Set 9 | hope
# Processing Record 35 of Set 9 | ponta do sol
# Processing Record 36 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 9 | galveston
# Processing Record 38 of Set 9 | severnoye
# Processing Record 39 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 9 | santa rosalia
# Processing Record 41 of Set 9 | puerto baquerizo moreno
# Processing Record 42 of Set 9 | staryy nadym
# Processing Record 43 of Set 9 | beringovskiy
# Processing Record 44 of Set 9 | iqaluit
# Processing Record 45 of Set 9 | sur
# Processing Record 46 of Set 9 | umm lajj
# Processing Record 47 of Set 9 | puerto quijarro
# Processing Record 48 of Set 9 | aykhal
# Processing Record 49 of Set 9 | rupert
# Processing Record 50 of Set 9 | mount barker
# Processing Record 1 of Set 10 | atyashevo
# Processing Record 2 of Set 10 | westport
# Processing Record 3 of Set 10 | ternate
# Processing Record 4 of Set 10 | omboue
# Processing Record 5 of Set 10 | moron
# Processing Record 6 of Set 10 | udachnyy
# Processing Record 7 of Set 10 | seondha
# Processing Record 8 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 9 of Set 10 | hokitika
# Processing Record 10 of Set 10 | mbini
# Processing Record 11 of Set 10 | kahului
# Processing Record 12 of Set 10 | waipawa
# Processing Record 13 of Set 10 | champerico
# Processing Record 14 of Set 10 | vredendal
# Processing Record 15 of Set 10 | price
# Processing Record 16 of Set 10 | kouango
# Processing Record 17 of Set 10 | bima
# Processing Record 18 of Set 10 | saint-georges
# Processing Record 19 of Set 10 | williston
# Processing Record 20 of Set 10 | malpe
# Processing Record 21 of Set 10 | walvis bay
# Processing Record 22 of Set 10 | saint helens
# Processing Record 23 of Set 10 | pundaguitan
# Processing Record 24 of Set 10 | merauke
# Processing Record 25 of Set 10 | crateus
# Processing Record 26 of Set 10 | margate
# Processing Record 27 of Set 10 | arlit
# Processing Record 28 of Set 10 | tari
# Processing Record 29 of Set 10 | bafoulabe
# Processing Record 30 of Set 10 | tortoli
# Processing Record 31 of Set 10 | chekhov
# Processing Record 32 of Set 10 | wufeng
# Processing Record 33 of Set 10 | okhotsk
# Processing Record 34 of Set 10 | gazanjyk
# Processing Record 35 of Set 10 | conde
# Processing Record 36 of Set 10 | jalu
# Processing Record 37 of Set 10 | tsabong
# Processing Record 38 of Set 10 | trelew
# Processing Record 39 of Set 10 | awbari
# Processing Record 40 of Set 10 | kardla
# Processing Record 41 of Set 10 | shevchenkove
# Processing Record 42 of Set 10 | bonavista
# Processing Record 43 of Set 10 | rocha
# Processing Record 44 of Set 10 | mazagao
# Processing Record 45 of Set 10 | marystown
# Processing Record 46 of Set 10 | kabin buri
# Processing Record 47 of Set 10 | toora-khem
# Processing Record 48 of Set 10 | honiara
# Processing Record 49 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 10 | teknaf
# Processing Record 1 of Set 11 | kavaratti
# Processing Record 2 of Set 11 | hammerfest
# Processing Record 3 of Set 11 | fort-shevchenko
# Processing Record 4 of Set 11 | pandan
# Processing Record 5 of Set 11 | kaeo
# Processing Record 6 of Set 11 | vesoul
# Processing Record 7 of Set 11 | labrea
# Processing Record 8 of Set 11 | zhigansk
# Processing Record 9 of Set 11 | narasannapeta
# Processing Record 10 of Set 11 | sal rei
# Processing Record 11 of Set 11 | voznesenye
# Processing Record 12 of Set 11 | doha
# Processing Record 13 of Set 11 | nelson bay
# Processing Record 14 of Set 11 | le port
# Processing Record 15 of Set 11 | pangnirtung
# Processing Record 16 of Set 11 | grand gaube
# Processing Record 17 of Set 11 | cockburn town
# Processing Record 18 of Set 11 | oktyabrskiy
# Processing Record 19 of Set 11 | yangambi
# Processing Record 20 of Set 11 | plattsburgh
# Processing Record 21 of Set 11 | po
# City not found. Skipping...
# Processing Record 22 of Set 11 | berlevag
# Processing Record 23 of Set 11 | redmond
# Processing Record 24 of Set 11 | tautira
# Processing Record 25 of Set 11 | sao joao da barra
# Processing Record 26 of Set 11 | karabulak
# Processing Record 27 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 28 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 11 | homer
# Processing Record 30 of Set 11 | torbat-e jam
# Processing Record 31 of Set 11 | castrillon
# Processing Record 32 of Set 11 | sao jose da coroa grande
# Processing Record 33 of Set 11 | alice springs
# Processing Record 34 of Set 11 | araguaina
# Processing Record 35 of Set 11 | muisne
# Processing Record 36 of Set 11 | saint-paul
# Processing Record 37 of Set 11 | waddan
# Processing Record 38 of Set 11 | wewak
# Processing Record 39 of Set 11 | lerwick
# Processing Record 40 of Set 11 | karasjok
# Processing Record 41 of Set 11 | isangel
# Processing Record 42 of Set 11 | usinsk
# Processing Record 43 of Set 11 | budesti
# Processing Record 44 of Set 11 | leirvik
# Processing Record 45 of Set 11 | malakal
# Processing Record 46 of Set 11 | eyl
# Processing Record 47 of Set 11 | the valley
# Processing Record 48 of Set 11 | qorveh
# Processing Record 49 of Set 11 | lewisporte
# Processing Record 50 of Set 11 | nurota
# Processing Record 1 of Set 12 | kemi
# Processing Record 2 of Set 12 | arnold
# Processing Record 3 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 12 | makakilo city
# Processing Record 5 of Set 12 | uige
# Processing Record 6 of Set 12 | naples
# Processing Record 7 of Set 12 | keflavik
# Processing Record 8 of Set 12 | cap malheureux
# Processing Record 9 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 10 of Set 12 | jacareacanga
# Processing Record 11 of Set 12 | sabang
# Processing Record 12 of Set 12 | mount gambier
# Processing Record 13 of Set 12 | lasem
# Processing Record 14 of Set 12 | bombay
# Processing Record 15 of Set 12 | la libertad
# Processing Record 16 of Set 12 | lithakia
# Processing Record 17 of Set 12 | xining
# Processing Record 18 of Set 12 | kutum
# Processing Record 19 of Set 12 | morbegno
# Processing Record 20 of Set 12 | beloha
# Processing Record 21 of Set 12 | ak-dovurak
# Processing Record 22 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 12 | dhing
# Processing Record 24 of Set 12 | manta
# Processing Record 25 of Set 12 | goderich
# Processing Record 26 of Set 12 | whitianga
# Processing Record 27 of Set 12 | teguldet
# Processing Record 28 of Set 12 | morris
# Processing Record 29 of Set 12 | dalnerechensk
# Processing Record 30 of Set 12 | port victoria
# Processing Record 31 of Set 12 | preobrazheniye
# Processing Record 32 of Set 12 | sitka
# Processing Record 33 of Set 12 | cabra
# Processing Record 34 of Set 12 | warrington
# Processing Record 35 of Set 12 | hauterive
# Processing Record 36 of Set 12 | itarema
# Processing Record 37 of Set 12 | lander
# Processing Record 38 of Set 12 | piet retief
# Processing Record 39 of Set 12 | ordzhonikidzevskaya
# Processing Record 40 of Set 12 | liku
# Processing Record 41 of Set 12 | wattegama
# Processing Record 42 of Set 12 | stornoway
# Processing Record 43 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 44 of Set 12 | sao gabriel da cachoeira
# Processing Record 45 of Set 12 | governador valadares
# Processing Record 46 of Set 12 | acarau
# Processing Record 47 of Set 12 | vanavara
# Processing Record 48 of Set 12 | souillac
# Processing Record 49 of Set 12 | dinguiraye
# Processing Record 50 of Set 12 | apiai
# Processing Record 1 of Set 13 | tiksi
# Processing Record 2 of Set 13 | udalguri
# Processing Record 3 of Set 13 | lasa
# Processing Record 4 of Set 13 | gelgaudiskis
# Processing Record 5 of Set 13 | paita
# Processing Record 6 of Set 13 | talnakh
# Processing Record 7 of Set 13 | anadyr
# Processing Record 8 of Set 13 | mayumba
# Processing Record 9 of Set 13 | nemuro
# Processing Record 10 of Set 13 | hemnesberget
# Processing Record 11 of Set 13 | wageningen
# Processing Record 12 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 13 of Set 13 | cordeiro
# Processing Record 14 of Set 13 | chute-aux-outardes
# Processing Record 15 of Set 13 | bria
# Processing Record 16 of Set 13 | muzaffarpur
# Processing Record 17 of Set 13 | canguaretama
# Processing Record 18 of Set 13 | tiznit
# Processing Record 19 of Set 13 | vila do maio
# Processing Record 20 of Set 13 | shimoda
# Processing Record 21 of Set 13 | solginskiy
# Processing Record 22 of Set 13 | sao domingos do maranhao
# Processing Record 23 of Set 13 | mendahara
# City not found. Skipping...
# Processing Record 24 of Set 13 | kikwit
# Processing Record 25 of Set 13 | houlton
# Processing Record 26 of Set 13 | moravsky pisek
# Processing Record 27 of Set 13 | jaguaruna
# Processing Record 28 of Set 13 | teeli
# Processing Record 29 of Set 13 | san policarpo
# Processing Record 30 of Set 13 | saint-louis
# Processing Record 31 of Set 13 | bayburt
# Processing Record 32 of Set 13 | batticaloa
# Processing Record 33 of Set 13 | taltal
# Processing Record 34 of Set 13 | araouane
# Processing Record 35 of Set 13 | sayyan
# Processing Record 36 of Set 13 | ola
# Processing Record 37 of Set 13 | sandwick
# Processing Record 38 of Set 13 | rio verde de mato grosso
# Processing Record 39 of Set 13 | lata
# Processing Record 40 of Set 13 | vilhena
# Processing Record 41 of Set 13 | sukhumi
# Processing Record 42 of Set 13 | antofagasta
# Processing Record 43 of Set 13 | konyshevka
# Processing Record 44 of Set 13 | fort nelson
# Processing Record 45 of Set 13 | tolstoy-yurt
# Processing Record 46 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 13 | nouakchott
# Processing Record 48 of Set 13 | tashtyp
# Processing Record 49 of Set 13 | tonantins
# Processing Record 50 of Set 13 | luanda
# Processing Record 1 of Set 14 | kirakira
# Processing Record 2 of Set 14 | iquitos
# Processing Record 3 of Set 14 | romilly-sur-seine
# Processing Record 4 of Set 14 | burica
# City not found. Skipping...
# Processing Record 5 of Set 14 | dalvik
# Processing Record 6 of Set 14 | ondjiva
# Processing Record 7 of Set 14 | pringsewu
# Processing Record 8 of Set 14 | lamu
# Processing Record 9 of Set 14 | konevo
# Processing Record 10 of Set 14 | nuristan
# Processing Record 11 of Set 14 | chingirlau
# Processing Record 12 of Set 14 | soe
# Processing Record 13 of Set 14 | kirsanov
# Processing Record 14 of Set 14 | noyabrsk
# Processing Record 15 of Set 14 | deep river
# Processing Record 16 of Set 14 | akdepe
# Processing Record 17 of Set 14 | solton
# Processing Record 18 of Set 14 | mwense
# Processing Record 19 of Set 14 | abu kamal
# Processing Record 20 of Set 14 | college
# Processing Record 21 of Set 14 | anito
# Processing Record 22 of Set 14 | sabzevar
# Processing Record 23 of Set 14 | londrina
# Processing Record 24 of Set 14 | sandur
# Processing Record 25 of Set 14 | dargaville
# Processing Record 26 of Set 14 | ariquemes
# Processing Record 27 of Set 14 | bereda
# Processing Record 28 of Set 14 | banyo
# Processing Record 29 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 30 of Set 14 | solnechnyy
# Processing Record 31 of Set 14 | taoudenni
# Processing Record 32 of Set 14 | tugolesskiy bor
# Processing Record 33 of Set 14 | mantua
# Processing Record 34 of Set 14 | verkh-usugli
# Processing Record 35 of Set 14 | eloy
# Processing Record 36 of Set 14 | sola
# Processing Record 37 of Set 14 | maunabo
# Processing Record 38 of Set 14 | miandrivazo
# Processing Record 39 of Set 14 | togul
# Processing Record 40 of Set 14 | bambanglipuro
# Processing Record 41 of Set 14 | romny
# Processing Record 42 of Set 14 | kysyl-syr
# Processing Record 43 of Set 14 | batemans bay
# Processing Record 44 of Set 14 | coahuayana
# Processing Record 45 of Set 14 | nosy varika
# Processing Record 46 of Set 14 | podporozhye
# Processing Record 47 of Set 14 | comodoro rivadavia
# Processing Record 48 of Set 14 | qaqortoq
# Processing Record 49 of Set 14 | moiyabana
# City not found. Skipping...
# Processing Record 50 of Set 14 | coihaique
# Processing Record 1 of Set 15 | pauini
# Processing Record 2 of Set 15 | puerto padre
# Processing Record 3 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 15 | te anau
# Processing Record 5 of Set 15 | gamba
# Processing Record 6 of Set 15 | puerto del rosario
# Processing Record 7 of Set 15 | kamenka
# Processing Record 8 of Set 15 | mehamn
# Processing Record 9 of Set 15 | raahe
# Processing Record 10 of Set 15 | sawtell
# Processing Record 11 of Set 15 | buin
# Processing Record 12 of Set 15 | skjervoy
# Processing Record 13 of Set 15 | joao pinheiro
# Processing Record 14 of Set 15 | namibe
# Processing Record 15 of Set 15 | rocky mountain house
# Processing Record 16 of Set 15 | chicama
# Processing Record 17 of Set 15 | vangaindrano
# Processing Record 18 of Set 15 | sokolskoye
# Processing Record 19 of Set 15 | abha
# Processing Record 20 of Set 15 | dakar
# Processing Record 21 of Set 15 | vila
# Processing Record 22 of Set 15 | nushki
# Processing Record 23 of Set 15 | san vicente
# Processing Record 24 of Set 15 | hatta
# Processing Record 25 of Set 15 | laurel
# Processing Record 26 of Set 15 | graaff-reinet
# Processing Record 27 of Set 15 | sitia
# Processing Record 28 of Set 15 | namtsy
# Processing Record 29 of Set 15 | lopatino
# Processing Record 30 of Set 15 | dudinka
# Processing Record 31 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 15 | kamina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 75.22,
#   'feels_like': 75.49,
#   'temp_min': 71.69,
#   'temp_max': 78.53,
#   'pressure': 1021,
#   'humidity': 65},
#  'visibility': 10000,
#  'wind': {'speed': 3, 'deg': 155, 'gust': 8.99},
#  'clouds': {'all': 90},
#  'dt': 1628096829,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1628070004,
#   'sunset': 1628121630},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
new_city_data_df = pd.DataFrame(city_data)
new_city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mogadishu      SO   2.0371   45.3438     76.32        85          74
# 1    Punta Arenas      CL -53.1500  -70.9167     57.31        55           0
# 2     Great Falls      US  47.5002 -111.3008     83.66        26           1
# 3           Vaini      TO -21.2000 -175.2000     64.56        77          40
# 4    Port Lincoln      AU -34.7333  135.8667     55.31        78          99
# 5       Hithadhoo      MV  -0.6000   73.0833     82.02        77         100
# 6          Albany      US  42.6001  -73.9662     78.80        61         100
# 7     New Norfolk      AU -42.7826  147.0587     47.71        65          99
# 8           Kapaa      US  22.0752 -159.3190     80.92        77          75
# 9  Saint-Augustin      CA  51.2260  -58.6502     70.16        43          46
#
#    Wind Speed Current Description
# 0       17.34          light rain
# 1        8.05           clear sky
# 2        1.99                haze
# 3        4.61    scattered clouds
# 4       10.29     overcast clouds
# 5        8.90     overcast clouds
# 6        4.18     overcast clouds
# 7        3.00     overcast clouds
# 8        4.00          light rain
# 9       14.61    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
